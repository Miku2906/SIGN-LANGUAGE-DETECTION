# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 871.9/871.9 kB 21.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/SignLanguageDetection/yolov8n.pt")
results = model.train(data="/content/drive/MyDrive/SignLanguageDetection/dataset.yaml",
                      epochs=30, optimizer='Adam', batch=32, patience=10, verbose=True,
                      project="/content/drive/MyDrive/SignLanguageDetection/results/", name="P")
# Out:
# Ultralytics YOLOv8.2.92 🚀 Python-3.10.12 torch-2.4.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...
